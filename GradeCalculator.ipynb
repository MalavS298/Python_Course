# %% [markdown]
# <a href="https://colab.research.google.com/github/MalavS298/Python_Course/blob/master/GradeCalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# def calculate_grade(grades):
#   if len(grades) == 0:
#     return "No Grades Provided"
#   average = sum(grades) / len(grades)

#   if average>= 90:
#     letter = "A"
#   elif average>= 80:
#     letter = "B"
#   elif average>= 70:
#     letter = "C"

#   return(f"Average: {average:}  Grade: {letter}")

# my_grades = [88, 91, 95, 98, 84]
# print(calculate_grade(my_grades))

# students = {
#     "Maria": [88,95,61,75],
#     "Jose":[84,58,61]
# }


def calculate_grade(grades):
    if len(grades) == 0:
        return "No Grades Provided"

    average = sum(grades) / len(grades)

    if average >= 90:
        letter = "A"
    elif average >= 80:
        letter = "B"
    elif average >= 70:
        letter = "C"
    elif average >= 60:
        letter = "D"
    else:
        letter = "F"

    return average, letter


students = {
    "Maria": [88, 95, 61, 75],
    "Jose": [84, 58, 61]
}

# Loop through all students
for name, grades in students.items():
    avg, letter = calculate_grade(grades)
    print(f"Name: {name}, Average: {avg:.1f}, Grade: {letter}")
# Out:
# Name: Maria, Average: 79.8, Grade: C
# Name: Jose, Average: 67.7, Grade: D
